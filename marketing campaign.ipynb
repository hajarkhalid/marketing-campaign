# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df= pd.read_csv(r"D:\marketing_data.csv")
df
# Out:
#          ID  Year_Birth   Education Marital_Status      Income   Kidhome  \
# 0      1826        1970  Graduation       Divorced  $84,835.00         0
# 1         1        1961  Graduation         Single  $57,091.00         0
# 2     10476        1958  Graduation        Married  $67,267.00         0
# 3      1386        1967  Graduation       Together  $32,474.00         1
# 4      5371        1989  Graduation         Single  $21,474.00         1
# ...     ...         ...         ...            ...          ...      ...
# 2235  10142        1976         PhD       Divorced  $66,476.00         0
# 2236   5263        1977    2n Cycle        Married  $31,056.00         1
# 2237     22        1976  Graduation       Divorced  $46,310.00         1
# 2238    528        1978  Graduation        Married  $65,819.00         0
# 2239   4070        1969         PhD        Married  $94,871.00         0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  NumStorePurchases  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2240 entries, 0 to 2239
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ID                   2240 non-null   int64
#  1   Year_Birth           2240 non-null   int64
#  2   Education            2240 non-null   object
#  3   Marital_Status       2240 non-null   object
#  4    Income              2216 non-null   object
#  5   Kidhome              2240 non-null   int64
#  6   Teenhome             2240 non-null   int64
#  7   Dt_Customer          2240 non-null   object
#  8   Recency              2240 non-null   int64
#  9   MntWines             2240 non-null   int64
#  10  MntFruits            2240 non-null   int64
#  11  MntMeatProducts      2240 non-null   int64
#  12  MntFishProducts      2240 non-null   int64
#  13  MntSweetProducts     2240 non-null   int64
#  14  MntGoldProds         2240 non-null   int64
# ...

# %%
df.describe()
# Out:
#                  ID   Year_Birth      Kidhome     Teenhome      Recency  \
# count   2240.000000  2240.000000  2240.000000  2240.000000  2240.000000
# mean    5592.159821  1968.805804     0.444196     0.506250    49.109375
# std     3246.662198    11.984069     0.538398     0.544538    28.962453
# min        0.000000  1893.000000     0.000000     0.000000     0.000000
# 25%     2828.250000  1959.000000     0.000000     0.000000    24.000000
# 50%     5458.500000  1970.000000     0.000000     0.000000    49.000000
# 75%     8427.750000  1977.000000     1.000000     1.000000    74.000000
# max    11191.000000  1996.000000     2.000000     2.000000    99.000000
#
#           MntWines    MntFruits  MntMeatProducts  MntFishProducts  \
# count  2240.000000  2240.000000      2240.000000      2240.000000
# mean    303.935714    26.302232       166.950000        37.525446
# std     336.597393    39.773434       225.715373        54.628979
# ...

# %%
df.columns = df.columns.str.replace(' ', '')
df["Income"] = df["Income"].str.replace('$','')
df["Income"] = df["Income"].str.replace(',','').astype('float')
df
# Out:
#          ID  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced  84835.0        0
# 1         1        1961  Graduation         Single  57091.0        0
# 2     10476        1958  Graduation        Married  67267.0        0
# 3      1386        1967  Graduation       Together  32474.0        1
# 4      5371        1989  Graduation         Single  21474.0        1
# ...     ...         ...         ...            ...      ...      ...
# 2235  10142        1976         PhD       Divorced  66476.0        0
# 2236   5263        1977    2n Cycle        Married  31056.0        1
# 2237     22        1976  Graduation       Divorced  46310.0        1
# 2238    528        1978  Graduation        Married  65819.0        0
# 2239   4070        1969         PhD        Married  94871.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  NumStorePurchases  \
# ...

# %%
df["Dt_Customer"]=pd.to_datetime(df["Dt_Customer"])
df
# Out:
#          ID  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced  84835.0        0
# 1         1        1961  Graduation         Single  57091.0        0
# 2     10476        1958  Graduation        Married  67267.0        0
# 3      1386        1967  Graduation       Together  32474.0        1
# 4      5371        1989  Graduation         Single  21474.0        1
# ...     ...         ...         ...            ...      ...      ...
# 2235  10142        1976         PhD       Divorced  66476.0        0
# 2236   5263        1977    2n Cycle        Married  31056.0        1
# 2237     22        1976  Graduation       Divorced  46310.0        1
# 2238    528        1978  Graduation        Married  65819.0        0
# 2239   4070        1969         PhD        Married  94871.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  NumStorePurchases  \
# ...

# %%
df.isna().sum()
# Out:
# ID                      0
# Year_Birth              0
# Education               0
# Marital_Status          0
# Income                 24
# Kidhome                 0
# Teenhome                0
# Dt_Customer             0
# Recency                 0
# MntWines                0
# MntFruits               0
# MntMeatProducts         0
# MntFishProducts         0
# MntSweetProducts        0
# MntGoldProds            0
# NumDealsPurchases       0
# NumWebPurchases         0
# NumCatalogPurchases     0
# NumStorePurchases       0
# NumWebVisitsMonth       0
# AcceptedCmp3            0
# AcceptedCmp4            0
# AcceptedCmp5            0
# AcceptedCmp1            0
# AcceptedCmp2            0
# Response                0
# Complain                0
# Country                 0
# dtype: int64

# %%
ax = sns.boxplot(x="Income",
                 data= df, palette="tab20_r")

# %%
plt.figure(figsize=(8,4))
sns.distplot(df["Income"],kde=False)
plt.title('income distribution')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
df['Income'] = df['Income'].fillna(df['Income'].median()) 
df
# Out:
#          ID  Year_Birth   Education Marital_Status   Income  Kidhome  \
# 0      1826        1970  Graduation       Divorced  84835.0        0
# 1         1        1961  Graduation         Single  57091.0        0
# 2     10476        1958  Graduation        Married  67267.0        0
# 3      1386        1967  Graduation       Together  32474.0        1
# 4      5371        1989  Graduation         Single  21474.0        1
# ...     ...         ...         ...            ...      ...      ...
# 2235  10142        1976         PhD       Divorced  66476.0        0
# 2236   5263        1977    2n Cycle        Married  31056.0        1
# 2237     22        1976  Graduation       Divorced  46310.0        1
# 2238    528        1978  Graduation        Married  65819.0        0
# 2239   4070        1969         PhD        Married  94871.0        0
#
#       Teenhome Dt_Customer  Recency  MntWines  ...  NumStorePurchases  \
# ...

# %%
df1 = df.drop(columns=['ID', 'AcceptedCmp1', 'AcceptedCmp2', 'AcceptedCmp3', 'AcceptedCmp4', 'AcceptedCmp5', 'Response', 'Complain']).select_dtypes(include=np.number)
df1
# Out:
#       Year_Birth   Income  Kidhome  Teenhome  Recency  MntWines  MntFruits  \
# 0           1970  84835.0        0         0        0       189        104
# 1           1961  57091.0        0         0        0       464          5
# 2           1958  67267.0        0         1        0       134         11
# 3           1967  32474.0        1         1        0        10          0
# 4           1989  21474.0        1         0        0         6         16
# ...          ...      ...      ...       ...      ...       ...        ...
# 2235        1976  66476.0        0         1       99       372         18
# 2236        1977  31056.0        1         0       99         5         10
# 2237        1976  46310.0        1         0       99       185          2
# 2238        1978  65819.0        0         0       99       267         38
# 2239        1969  94871.0        0         2       99       169         24
#
# ...

# %%
df1.plot(subplots=True, layout=(4,4), kind='box', figsize=(12,14))
plt.subplots_adjust(wspace=0.5)

# %%
df = df[df['Year_Birth'] > 1900].reset_index(drop=True)
plt.figure(figsize=(3,4))
df['Year_Birth'].plot(kind='box')
# Out:
# <AxesSubplot:>

# %%
df['Dependents'] = df['Kidhome'] + df['Teenhome']

# Year becoming a Customer
df['Year_Customer'] = pd.DatetimeIndex(df['Dt_Customer']).year

# Total Amount Spent
mnt_cols = [col for col in df.columns if 'Mnt' in col]
df['TotalMnt'] = df[mnt_cols].sum(axis=1)

# Total Purchases
purchases_cols = [col for col in df.columns if 'Purchases' in col]
df['TotalPurchases'] = df[purchases_cols].sum(axis=1)

# Total Campaigns Accepted
campaigns_cols = [col for col in df.columns if 'Cmp' in col] + ['Response'] # 'Response' is for the latest campaign
df['TotalCampaignsAcc'] = df[campaigns_cols].sum(axis=1)

# view new features, by customer ID
df[['ID', 'Dependents', 'Year_Customer', 'TotalMnt', 'TotalPurchases', 'TotalCampaignsAcc']].head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18168/3416850888.py in <module>
#      17
#      18 # view new features, by customer ID
# ---> 19 df[['ID', 'Dependents', 'Year_Customer', 'TotalMnt', 'TotalPurchases', 'TotalCampaignsAcc']].head()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
# ...

# %%
plt.figure(1 , figsize = (15 , 6))
n = 0 
for x in ['Year_Customer' , 'TotalPurchases' , 'TotalMnt','TotalCampaignsAcc','Dependents']:
    n += 1
    plt.subplot(1 ,5, n)
    plt.subplots_adjust(hspace =0.5 , wspace = 0.5)
    sns.distplot(df[x] , bins = 20)
    plt.title('Distplot of {}'.format(x))
plt.show()

# %%
plt.figure(1 , figsize = (15 , 7))
n = 0 
for x in ['Year_Customer' , 'TotalPurchases' , 'TotalMnt','TotalCampaignsAcc','Dependents']:
    for y in ['Year_Customer' , 'TotalPurchases' , 'TotalMnt','TotalCampaignsAcc','Dependents']:
        n += 1
        plt.subplot(3 , 5 , n)
        plt.subplots_adjust(hspace = 0.5 , wspace = 0.5)
        sns.regplot(x = x , y = y , data = df)
        plt.ylabel(y.split()[0]+' '+y.split()[1] if len(y.split()) > 1 else y )
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_18168/960423281.py in <module>
#       4     for y in ['Year_Customer' , 'TotalPurchases' , 'TotalMnt','TotalCampaignsAcc','Dependents']:
#       5         n += 1
# ----> 6         plt.subplot(3 , 5 , n)
#       7         plt.subplots_adjust(hspace = 0.5 , wspace = 0.5)
#       8         sns.regplot(x = x , y = y , data = df)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in subplot(*args, **kwargs)
#    1270
#    1271     # First, search for an existing subplot with a matching spec.
# -> 1272     key = SubplotSpec._from_subplot_args(fig, args)
#    1273
#    1274     for ax in fig.axes:
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\gridspec.py in _from_subplot_args(figure, args)
#     651                     num = int(num)
# ...

# %%
plt.figure(1 , figsize = (15 , 7))
n = 0 
for cols in ['Year_Customer' , 'TotalPurchases' , 'TotalMnt','TotalCampaignsAcc','Dependents']:
    n += 1 
    plt.subplot(1 , 5 , n)
    plt.subplots_adjust(hspace = 0.5 , wspace = 0.5)
    sns.violinplot(x = cols , y = 'Dependents' , data = df , palette = 'vlag')
    sns.swarmplot(x = cols , y = 'Dependents' , data = df)
    plt.ylabel('Dependents' if n == 1 else '')
    plt.title('Boxplots & Swarmplots' if n == 2 else '')
plt.show()

# %%
plt.figure(1 , figsize = (15 , 7))
n = 0 
for cols in ['Year_Customer' , 'TotalPurchases' , 'TotalMnt','TotalCampaignsAcc','Dependents']:
    n += 1 
    plt.subplot(1 , 5 , n)
    plt.subplots_adjust(hspace = 0.5 , wspace = 0.5)
    sns.violinplot(x = cols , y = 'Kidhome' , data = df , palette = 'vlag')
    sns.swarmplot(x = cols , y = 'Teenhome' , data = df)
    plt.ylabel('Dependents' if n == 1 else '')
    plt.title('Boxplots & Swarmplots' if n == 2 else '')
plt.show()

# %%
df.drop('ID', axis=1, inplace = True)
df.drop(('Kidhome','Teenhome'),axis=1, inplace =True)
df.head()

# %%
df['Dependents'] = df['Kidhome'] + df['Teenhome']
df
# Out:
#       Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0           1970  Graduation       Divorced  84835.0        0         0
# 1           1961  Graduation         Single  57091.0        0         0
# 2           1958  Graduation        Married  67267.0        0         1
# 3           1967  Graduation       Together  32474.0        1         1
# 4           1989  Graduation         Single  21474.0        1         0
# ...          ...         ...            ...      ...      ...       ...
# 2232        1976         PhD       Divorced  66476.0        0         1
# 2233        1977    2n Cycle        Married  31056.0        1         0
# 2234        1976  Graduation       Divorced  46310.0        1         0
# 2235        1978  Graduation        Married  65819.0        0         0
# 2236        1969         PhD        Married  94871.0        0         2
#
#      Dt_Customer  Recency  MntWines  MntFruits  ...  AcceptedCmp1  \
# ...

# %%
corr = df1.corr()
sns.set(font_scale=1.4)
plt.figure(figsize=(9,8))
sns.heatmap(cor, annot=True, cmap='plasma')
plt.tight_layout()
plt.show()

# %%
cmap = cmap=sns.diverging_palette(5, 250, as_cmap=True)

def magnify():
    return [dict(selector="th",
                 props=[("font-size", "7pt")]),
            dict(selector="td",
                 props=[('padding', "0em 0em")]),
            dict(selector="th:hover",
                 props=[("font-size", "12pt")]),
            dict(selector="tr:hover td:hover",
                 props=[('max-width', '200px'),
                        ('font-size', '12pt')])
]

corr.style.background_gradient(cmap, axis=1)\
    .set_properties(**{'max-width': '80px', 'font-size': '10pt'})\
    .set_caption("Hover to magify")\
    .set_precision(2)\
    .set_table_styles(magnify())
# Out:
# <style type="text/css">
# #T_73dfc_ th {
#   font-size: 7pt;
# }
# #T_73dfc_ td {
#   padding: 0em 0em;
# }
# #T_73dfc_ th:hover {
#   font-size: 12pt;
# }
# #T_73dfc_ tr:hover td:hover {
#   max-width: 200px;
#   font-size: 12pt;
# }
# #T_73dfc_row0_col0, #T_73dfc_row1_col1, #T_73dfc_row2_col2, #T_73dfc_row3_col3, #T_73dfc_row4_col4, #T_73dfc_row5_col5, #T_73dfc_row6_col6, #T_73dfc_row7_col7, #T_73dfc_row8_col8, #T_73dfc_row9_col9, #T_73dfc_row10_col10, #T_73dfc_row11_col11, #T_73dfc_row12_col12, #T_73dfc_row13_col13, #T_73dfc_row14_col14, #T_73dfc_row15_col15 {
#   background-color: #4479bb;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_73dfc_row0_col1, #T_73dfc_row0_col5, #T_73dfc_row3_col9, #T_73dfc_row15_col5 {
#   background-color: #df7086;
#   color: #f1f1f1;
#   max-width: 80px;
#   font-size: 10pt;
# }
# #T_73dfc_row0_col2, #T_73dfc_row15_col3 {
#   background-color: #efdcdf;
#   color: #000000;
#   max-width: 80px;
#   font-size: 10pt;
# }
# ...
